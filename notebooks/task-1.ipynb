# %% [markdown]
# ## Importing Libraries
#
# This section sets up the Python environment for data analysis and visualization:
#
# - **pandas**: For data manipulation and analysis.
# - **matplotlib.pyplot**: For creating static, animated, and interactive visualizations.
# - **seaborn**: For advanced statistical data visualization, built on top of matplotlib.
# - **warnings**: To suppress non-critical warning messages for cleaner output.
# - **sys, os**: For system path management, allowing the import of custom scripts.
#
# The line `sys.path.append(os.path.abspath("../scripts"))` adds the `scripts` directory (located one level above the current working directory) to the Python path. This enables importing custom modules, such as `eda_stats.py`, which contains user-defined functions for exploratory data analysis and statistics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
import os

# Configure warnings (suppress non-critical warnings)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

sys.path.append(os.path.abspath("../scripts"))

from eda_stats import *

# %% [markdown]
# ### **Data Loading**

# %%
df = data_loading(r"..\data\MachineLearningRating_v3.txt")

df.head()
# Out:
#   UnderwrittenCoverID PolicyID     TransactionMonth IsVATRegistered  \
# 0              145249    12827  2015-03-01 00:00:00            True
# 1              145249    12827  2015-05-01 00:00:00            True
# 2              145249    12827  2015-07-01 00:00:00            True
# 3              145255    12827  2015-05-01 00:00:00            True
# 4              145255    12827  2015-07-01 00:00:00            True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0         NaN  Close Corporation    Mr  English  First National Bank
# 1         NaN  Close Corporation    Mr  English  First National Bank
# 2         NaN  Close Corporation    Mr  English  First National Bank
# 3         NaN  Close Corporation    Mr  English  First National Bank
# 4         NaN  Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# 0  Current account  ...             Mobility - Windscreen    Windscreen
# 1  Current account  ...             Mobility - Windscreen    Windscreen
# 2  Current account  ...             Mobility - Windscreen    Windscreen
# 3  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
# 4  Current account  ...  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#        TotalPremium    TotalClaims
# 0   21.929824561403  .000000000000
# 1   21.929824561403  .000000000000
# 2     .000000000000  .000000000000
# 3  512.848070175439  .000000000000
# 4     .000000000000  .000000000000
#
# [5 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  object
#  1   PolicyID                  1000098 non-null  object
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  object
#  4   Citizenship               104888 non-null   object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  object
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   object
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  object
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   object
#  24  cubiccapacity             999546 non-null   object
#  25  kilowatts                 999546 non-null   object
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   object
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   object
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        object
#  39  SumInsured                1000098 non-null  object
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  object
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  object
#  51  TotalClaims               1000098 non-null  object
# dtypes: object(52)
# memory usage: 396.8+ MB

# %% [markdown]
# ## Develop a Foundational Understanding of the Data
#
# ### Tasks
# - **Data Understanding**
# - **Exploratory Data Analysis (EDA)**
#
# ---
#
# ### Guiding Questions
#
# - What is the overall **Loss Ratio** (`TotalClaims / TotalPremium`) for the portfolio? How does it vary by **Province**, **VehicleType**, and **Gender**?
# - What are the distributions of key financial variables? Are there outliers in **TotalClaims** or **CustomValueEstimate** that could skew our analysis?
# - Are there temporal trends? Did the claim frequency or severity change over the 18-month period?
# - Which vehicle makes/models are associated with the highest and lowest claim amounts?
#
# ---
#
# ### Statistical Thinking & KPIs
#
# - **Proactivity to self-learn** – sharing references.
# - **EDA techniques** to understand data and discover insights.
# - Demonstrating statistical understanding by using suitable statistical distributions and plots to provide evidence for actionable insights gained from EDA.
#
# ---
#
# ### Minimum Essential To Do
#
# - Create a **GitHub repository** to host all code for this week.
# - Create at least one new branch called `task-1` for your analysis of day 1.
# - Commit your work at least three times a day with a descriptive commit message.
#
# ---
#
# ### Perform Exploratory Data Analysis (EDA) on the Following:
#
# #### Data Summarization
# - **Descriptive Statistics**: Calculate the variability for numerical features such as `TotalPremium`, `TotalClaim`, etc.
#
# #### Data Structure
# - Review the dtype of each column to confirm if categorical variables, dates, etc. are properly formatted.
#
# #### Data Quality Assessment
# - Check for missing values.
#
# #### Univariate Analysis
# - **Distribution of Variables**: Plot histograms for numerical columns and bar charts for categorical columns to understand distributions.
#
# #### Bivariate or Multivariate Analysis
# - **Correlations and Associations**: Explore relationships between the monthly changes in `TotalPremium` and `TotalClaims` as a function of `ZipCode`, using scatter plots and correlation matrices.
#
# #### Data Comparison
# - **Trends Over Geography**: Compare the change in insurance cover type, premium, auto make, etc.
#
# #### Outlier Detection
# - Use box plots to detect outliers in numerical data.
#
# #### Visualization
# - Produce **3 creative and beautiful plots** that capture the key insights you gained from your EDA.

# %% [markdown]
# * ### **Checking Missed value**

# %%
missing = check_missing_values(df)
missing
# Out:
#                          MissingCount  Percentage
# Citizenship                    895210   89.512228
# Bank                           145961   14.594670
# AccountType                     40232    4.022806
# MaritalStatus                    8259    0.825819
# Gender                           9536    0.953507
# mmcode                            552    0.055195
# VehicleType                       552    0.055195
# make                              552    0.055195
# Model                             552    0.055195
# Cylinders                         552    0.055195
# cubiccapacity                     552    0.055195
# kilowatts                         552    0.055195
# bodytype                          552    0.055195
# NumberOfDoors                     552    0.055195
# VehicleIntroDate                  552    0.055195
# CustomValueEstimate            779642   77.956560
# CapitalOutstanding                  2    0.000200
# NewVehicle                     153295   15.327998
# WrittenOff                     641901   64.183810
# Rebuilt                        641901   64.183810
# Converted                      641901   64.183810
# CrossBorder                    999400   99.930207
# NumberOfVehiclesInFleet       1000098  100.000000

# %%
# Visualize the percentage of missing values for each feature using a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=missing.sort_values("Percentage", ascending=False),
    y=missing.index,
    x="Percentage",
    palette="viridis"
)
plt.title("Percentage of Missing Values by Feature")
plt.xlabel("Percentage Missing")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Missing Values
#
# - **High Missingness:**
#   - `NumberOfVehiclesInFleet` is missing in all records (100%), indicating it may not be relevant for this dataset or was not collected.
#   - `CrossBorder` (99.93%), `Citizenship` (89.51%), `CustomValueEstimate` (77.96%), `WrittenOff`, `Rebuilt`, and `Converted` (all 64.18%) have extremely high missing rates. These features may not be useful for most analyses unless missingness is meaningful or can be imputed.
# - **Moderate Missingness:**
#   - `NewVehicle` (15.33%) and `Bank` (14.59%) have moderate missing values. Analyses involving these features should consider imputation or exclusion strategies.
# - **Low Missingness:**
#   - Features like `AccountType` (4.02%), `MaritalStatus` (0.83%), `Gender` (0.95%), and several vehicle-related columns (all around 0.05%) have low missingness and can be handled with simple imputation or row removal.
#   - `CapitalOutstanding` has negligible missingness (0.0002%) and can be safely imputed or ignored.
#
# **Conclusion:**
# Several features have very high proportions of missing data and may need to be excluded from modeling or require special handling. Most other features have low missingness and can be managed with standard data cleaning techniques. The high missingness in some columns may indicate optional fields, data collection issues, or features not applicable to

# %% [markdown]
# ### Dropping Features with High Missing Values
#
# To ensure data quality and simplify analysis, we will remove features (columns) with more than 30% missing values. Features with excessive missingness are unlikely to provide reliable insights and may introduce bias or noise if imputed.
#
# **Steps:**
# 1. Identify columns where the percentage of missing values exceeds 30% using the `missing` DataFrame.
# 2. Drop these columns from the main DataFrame (`df`).
# 3. Document which columns were removed for transparency and reproducibility.
#
# This approach helps maintain a robust dataset for downstream analysis and modeling.

# %%
highly_missed_features = (missing[missing.Percentage > 30]).index.to_list()

# Drop the column

df.drop(columns=highly_missed_features, inplace=True)

print("DataFrame Shape", df.shape)
# Out:
# DataFrame Shape (1000098, 45)

# %%
missing_after_dropped = check_missing_values(df)
missing_after_dropped
# Out:
#                     MissingCount  Percentage
# Bank                      145961   14.594670
# AccountType                40232    4.022806
# MaritalStatus               8259    0.825819
# Gender                      9536    0.953507
# mmcode                       552    0.055195
# VehicleType                  552    0.055195
# make                         552    0.055195
# Model                        552    0.055195
# Cylinders                    552    0.055195
# cubiccapacity                552    0.055195
# kilowatts                    552    0.055195
# bodytype                     552    0.055195
# NumberOfDoors                552    0.055195
# VehicleIntroDate             552    0.055195
# CapitalOutstanding             2    0.000200
# NewVehicle                153295   15.327998

# %% [markdown]
# The code first uses `detect_dtype(df)` to analyze each column in the DataFrame and determine its most appropriate data type (such as integer, float, boolean, or string).
# Then, `convert_dtypes(df, columns_dtype)` converts each column in the DataFrame to its detected data type.
# This process ensures that all columns have the correct data types, which improves the accuracy and efficiency of subsequent data analysis.

# %%
columns_dtype = detect_dtype(df)
df = convert_dtypes(df, columns_dtype)

df["mmcode"] = df["mmcode"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  Int64
#  1   PolicyID                  1000098 non-null  Int64
#  2   TransactionMonth          1000098 non-null  datetime64[ns]
#  3   IsVATRegistered           1000098 non-null  bool
#  4   LegalType                 1000098 non-null  object
#  5   Title                     1000098 non-null  object
#  6   Language                  1000098 non-null  object
#  7   Bank                      854137 non-null   object
#  8   AccountType               959866 non-null   object
#  9   MaritalStatus             991839 non-null   object
#  10  Gender                    990562 non-null   object
#  11  Country                   1000098 non-null  object
#  12  Province                  1000098 non-null  object
#  13  PostalCode                1000098 non-null  Int64
#  14  MainCrestaZone            1000098 non-null  object
#  15  SubCrestaZone             1000098 non-null  object
#  16  ItemType                  1000098 non-null  object
#  17  mmcode                    1000098 non-null  object
#  18  VehicleType               999546 non-null   object
#  19  RegistrationYear          1000098 non-null  Int64
#  20  make                      999546 non-null   object
#  21  Model                     999546 non-null   object
#  22  Cylinders                 999546 non-null   float64
#  23  cubiccapacity             999546 non-null   float64
#  24  kilowatts                 999546 non-null   float64
#  25  bodytype                  999546 non-null   object
#  26  NumberOfDoors             999546 non-null   float64
#  27  VehicleIntroDate          999546 non-null   object
#  28  AlarmImmobiliser          1000098 non-null  bool
#  29  TrackingDevice            1000098 non-null  bool
#  30  CapitalOutstanding        1000096 non-null  object
#  31  NewVehicle                846803 non-null   object
#  32  SumInsured                1000098 non-null  float64
#  33  TermFrequency             1000098 non-null  object
#  34  CalculatedPremiumPerTerm  1000098 non-null  float64
#  35  ExcessSelected            1000098 non-null  object
#  36  CoverCategory             1000098 non-null  object
#  37  CoverType                 1000098 non-null  object
#  38  CoverGroup                1000098 non-null  object
#  39  Section                   1000098 non-null  object
#  40  Product                   1000098 non-null  object
#  41  StatutoryClass            1000098 non-null  object
#  42  StatutoryRiskType         1000098 non-null  object
#  43  TotalPremium              1000098 non-null  float64
#  44  TotalClaims               1000098 non-null  float64
# dtypes: Int64(4), bool(3), datetime64[ns](1), float64(8), object(29)
# memory usage: 327.1+ MB

# %%
# Show more rows
pd.set_option('display.max_rows', 100)

# Show more columns
pd.set_option('display.max_columns', 100)

# Widen the display in the notebook
pd.set_option('display.width', 200)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered          LegalType Title Language                 Bank      AccountType  MaritalStatus         Gender       Country Province  \
# 0               145249     12827       2015-03-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng
# 1               145249     12827       2015-05-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng
# 2               145249     12827       2015-07-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng
# 3               145255     12827       2015-05-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng
# 4               145255     12827       2015-07-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng
#
#    PostalCode MainCrestaZone SubCrestaZone          ItemType      mmcode        VehicleType  RegistrationYear           make  Model  Cylinders  cubiccapacity  kilowatts bodytype  NumberOfDoors  \
# 0        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D            4.0
# 1        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D            4.0
# 2        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D            4.0
# 3        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D            4.0
# 4        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D            4.0
#
#   VehicleIntroDate  AlarmImmobiliser  TrackingDevice CapitalOutstanding          NewVehicle  SumInsured TermFrequency  CalculatedPremiumPerTerm                    ExcessSelected CoverCategory  \
# 0           6/2002              True            True             119300  More than 6 months        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen
# 1           6/2002              True            True             119300  More than 6 months        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen
# 2           6/2002              True            True             119300  More than 6 months        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen
# 3           6/2002              True            True             119300  More than 6 months   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage
# 4           6/2002              True            True             119300  More than 6 months   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section                          Product StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant     21.929825          0.0
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant     21.929825          0.0
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant      0.000000          0.0
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant    512.848070          0.0
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant      0.000000          0.0

# %%
categorical_features = [col for col, d in columns_dtype.items() if d == "string"]
numerical_features = [col for col, d in columns_dtype.items() if d == "int" or d == "float"]
boolean_features = [col for col, d in columns_dtype.items() if d == "bool"]

print(f"Categorical Features ({len(categorical_features)}): {categorical_features}")
print(f"Numerical Features ({len(numerical_features)}): {numerical_features}")
print(f"Boolean Features ({len(boolean_features)}): {boolean_features}")
# Out:
# Categorical Features (28): ['LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'CapitalOutstanding', 'NewVehicle', 'TermFrequency', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType']
# Numerical Features (13): ['UnderwrittenCoverID', 'PolicyID', 'PostalCode', 'mmcode', 'RegistrationYear', 'Cylinders', 'cubiccapacity', 'kilowatts', 'NumberOfDoors', 'SumInsured', 'CalculatedPremiumPerTerm', 'TotalPremium', 'TotalClaims']
# Boolean Features (3): ['IsVATRegistered', 'AlarmImmobiliser', 'TrackingDevice']

# %%
missing_after_dropped.index.to_list()
# Out:
# ['Bank',
#  'AccountType',
#  'MaritalStatus',
#  'Gender',
#  'mmcode',
#  'VehicleType',
#  'make',
#  'Model',
#  'Cylinders',
#  'cubiccapacity',
#  'kilowatts',
#  'bodytype',
#  'NumberOfDoors',
#  'VehicleIntroDate',
#  'CapitalOutstanding',
#  'NewVehicle']

# %%
# Visualize the percentage of missing values for each feature using a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=missing_after_dropped.sort_values("Percentage", ascending=False),
    y=missing_after_dropped.index,
    x="Percentage",
    palette="viridis"
)
plt.title("Percentage of Missing Values by Feature")
plt.xlabel("Percentage Missing")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Imputation of missing values based on their data type

# %%
categorical_features_missing_data = [col for col in missing_after_dropped.index.to_list() if columns_dtype[col] == "string"]
numerical_features_missing_data = [col for col in missing_after_dropped.index.to_list() if columns_dtype[col] == "int" or columns_dtype[col] == "float"]
boolean_features_missing_data = [col for col in missing_after_dropped.index.to_list() if columns_dtype[col] == "bool"]

print(f"Categorical features with missing data ({len(categorical_features_missing_data)}): {categorical_features_missing_data}")
print(f"Numerical features with missing data ({len(numerical_features_missing_data)}): {numerical_features_missing_data}")
print(f"Boolean features with missing data ({len(boolean_features_missing_data)}): {boolean_features_missing_data}")
# Out:
# Categorical features with missing data (11): ['Bank', 'AccountType', 'MaritalStatus', 'Gender', 'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'CapitalOutstanding', 'NewVehicle']
# Numerical features with missing data (5): ['mmcode', 'Cylinders', 'cubiccapacity', 'kilowatts', 'NumberOfDoors']
# Boolean features with missing data (0): []

# %% [markdown]
# ### **Imputing missing values**

# %%
# Impute missing values: fill both numerical and categorical features

impute_missing_values(df, numerical_features=numerical_features_missing_data, categorical_features=categorical_features_missing_data)
# Out:
# Imputed missing values in 15 columns
# Columns imputed: Bank, AccountType, MaritalStatus, Gender, VehicleType, make, Model, Cylinders, cubiccapacity, kilowatts, bodytype, NumberOfDoors, VehicleIntroDate, CapitalOutstanding, NewVehicle
#          UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered          LegalType Title Language                 Bank      AccountType  MaritalStatus         Gender       Country  \
# 0                     145249     12827       2015-03-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 1                     145249     12827       2015-05-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 2                     145249     12827       2015-07-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 3                     145255     12827       2015-05-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 4                     145255     12827       2015-07-01             True  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# ...                      ...       ...              ...              ...                ...   ...      ...                  ...              ...            ...            ...           ...
# 1000093                31520       389       2015-04-01             True         Individual    Mr  English            ABSA Bank  Savings account         Single           Male  South Africa
# 1000094                31520       389       2015-06-01             True         Individual    Mr  English            ABSA Bank  Savings account         Single           Male  South Africa
# 1000095                31520       389       2015-08-01             True         Individual    Mr  English            ABSA Bank  Savings account         Single           Male  South Africa
# 1000096                31519       389       2014-07-01             True         Individual    Mr  English            ABSA Bank  Savings account         Single           Male  South Africa
# 1000097                31519       389       2015-02-01             True         Individual    Mr  English            ABSA Bank  Savings account         Single           Male  South Africa
#
#              Province  PostalCode                    MainCrestaZone    SubCrestaZone          ItemType      mmcode        VehicleType  RegistrationYear           make                  Model  \
# 0             Gauteng        1459                         Rand East        Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ                  E 240
# 1             Gauteng        1459                         Rand East        Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ                  E 240
# 2             Gauteng        1459                         Rand East        Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ                  E 240
# 3             Gauteng        1459                         Rand East        Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ                  E 240
# 4             Gauteng        1459                         Rand East        Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ                  E 240
# ...               ...         ...                               ...              ...               ...         ...                ...               ...            ...                    ...
# 1000093  Western Cape        7493  Karoo 1 (Northeast of Cape Town)  Northeast of CT  Mobility - Motor   4614100.0  Passenger Vehicle              2013          B.A.W  SASUKA 2.7i (16 SEAT)
# 1000094  Western Cape        7493  Karoo 1 (Northeast of Cape Town)  Northeast of CT  Mobility - Motor   4614100.0  Passenger Vehicle              2013          B.A.W  SASUKA 2.7i (16 SEAT)
# 1000095  Western Cape        7493  Karoo 1 (Northeast of Cape Town)  Northeast of CT  Mobility - Motor   4614100.0  Passenger Vehicle              2013          B.A.W  SASUKA 2.7i (16 SEAT)
# 1000096  Western Cape        7493  Karoo 1 (Northeast of Cape Town)  Northeast of CT  Mobility - Motor   4614100.0  Passenger Vehicle              2013          B.A.W  SASUKA 2.7i (16 SEAT)
# 1000097  Western Cape        7493  Karoo 1 (Northeast of Cape Town)  Northeast of CT  Mobility - Motor   4614100.0  Passenger Vehicle              2013          B.A.W  SASUKA 2.7i (16 SEAT)
#
#          Cylinders  cubiccapacity  kilowatts bodytype  NumberOfDoors        VehicleIntroDate  AlarmImmobiliser  TrackingDevice CapitalOutstanding          NewVehicle  SumInsured TermFrequency  \
# 0              6.0         2597.0      130.0      S/D            4.0                  6/2002              True            True             119300  More than 6 months        0.01       Monthly
# 1              6.0         2597.0      130.0      S/D            4.0                  6/2002              True            True             119300  More than 6 months        0.01       Monthly
# 2              6.0         2597.0      130.0      S/D            4.0                  6/2002              True            True             119300  More than 6 months        0.01       Monthly
# 3              6.0         2597.0      130.0      S/D            4.0                  6/2002              True            True             119300  More than 6 months   119300.00       Monthly
# 4              6.0         2597.0      130.0      S/D            4.0                  6/2002              True            True             119300  More than 6 months   119300.00       Monthly
# ...            ...            ...        ...      ...            ...                     ...               ...             ...                ...                 ...         ...           ...
# 1000093        4.0         2693.0      110.0      B/S            4.0  2013/01/01 12:00:00 AM              True            True                  0  More than 6 months   500000.00       Monthly
# 1000094        4.0         2693.0      110.0      B/S            4.0  2013/01/01 12:00:00 AM              True            True                  0  More than 6 months   500000.00       Monthly
# 1000095        4.0         2693.0      110.0      B/S            4.0  2013/01/01 12:00:00 AM              True            True                  0  More than 6 months   500000.00       Monthly
# 1000096        4.0         2693.0      110.0      B/S            4.0  2013/01/01 12:00:00 AM              True            True                  0  More than 6 months  5000000.00       Monthly
# 1000097        4.0         2693.0      110.0      B/S            4.0  2013/01/01 12:00:00 AM              True            True                  0  More than 6 months  5000000.00       Monthly
#
#          CalculatedPremiumPerTerm                    ExcessSelected        CoverCategory            CoverType            CoverGroup              Section                             Product  \
# 0                         25.0000             Mobility - Windscreen           Windscreen           Windscreen  Comprehensive - Taxi  Motor Comprehensive     Mobility Metered Taxis: Monthly
# 1                         25.0000             Mobility - Windscreen           Windscreen           Windscreen  Comprehensive - Taxi  Motor Comprehensive     Mobility Metered Taxis: Monthly
# 2                         25.0000             Mobility - Windscreen           Windscreen           Windscreen  Comprehensive - Taxi  Motor Comprehensive     Mobility Metered Taxis: Monthly
# 3                        584.6468  Mobility - Metered Taxis - R2000           Own damage           Own Damage  Comprehensive - Taxi  Motor Comprehensive     Mobility Metered Taxis: Monthly
# 4                        584.6468  Mobility - Metered Taxis - R2000           Own damage           Own Damage  Comprehensive - Taxi  Motor Comprehensive     Mobility Metered Taxis: Monthly
# ...                           ...                               ...                  ...                  ...                   ...                  ...                                 ...
# 1000093                  395.8481                         No excess          Third Party          Third Party  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000094                  395.8481                         No excess          Third Party          Third Party  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000095                  395.8481                         No excess          Third Party          Third Party  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000096                    2.6391                         No excess  Passenger Liability  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly
# 1000097                    2.6391                         No excess  Passenger Liability  Passenger Liability  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly
#
#         StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0           Commercial     IFRS Constant     21.929825          0.0
# 1           Commercial     IFRS Constant     21.929825          0.0
# 2           Commercial     IFRS Constant      0.000000          0.0
# 3           Commercial     IFRS Constant    512.848070          0.0
# 4           Commercial     IFRS Constant      0.000000          0.0
# ...                ...               ...           ...          ...
# 1000093     Commercial     IFRS Constant    347.235175          0.0
# 1000094     Commercial     IFRS Constant    347.235175          0.0
# 1000095     Commercial     IFRS Constant    347.235175          0.0
# 1000096     Commercial     IFRS Constant      2.315000          0.0
# 1000097     Commercial     IFRS Constant      2.315000          0.0
#
# [1000098 rows x 45 columns]

# %% [markdown]
# #### **What is the overall Loss Ratio (TotalClaims / TotalPremium) for the portfolio? How does it vary by Province, VehicleType, and Gender?**

# %%
# Calculate overall Loss Ratio for the portfolio
overall_loss_ratio = df['TotalClaims'].sum() / df['TotalPremium'].sum()
print(f"Overall Loss Ratio: {overall_loss_ratio:.4f}")

# Loss Ratio by Province
province_loss_ratio = df.groupby('Province').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by Province:")
print(province_loss_ratio)
## plot barplot 

# Loss Ratio by VehicleType
vehicle_type_loss_ratio = df.groupby('VehicleType').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by VehicleType:")
print(vehicle_type_loss_ratio)
## plot barplot 

# Loss Ratio by Gender
gender_loss_ratio = df.groupby('Gender').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by Gender:")
print(gender_loss_ratio)
## plot barplot
# Out:
# Overall Loss Ratio: 1.0477
#
# Loss Ratio by Province:
# Province
# Eastern Cape     0.633813
# Free State       0.680758
# Gauteng          1.222018
# KwaZulu-Natal    1.082693
# Limpopo          0.661199
# Mpumalanga       0.720897
# North West       0.790367
# Northern Cape    0.282699
# Western Cape     1.059472
# dtype: float64
#
# Loss Ratio by VehicleType:
# VehicleType
# Bus                  0.137292
# Heavy Commercial     1.628112
# Light Commercial     0.232066
# Medium Commercial    1.050251
# Passenger Vehicle    1.047538
# dtype: float64
#
# Loss Ratio by Gender:
# Gender
# Female           0.821879
# Male             0.883910
# Not specified    1.053204
# dtype: float64

# %%
# Plot Loss Ratio by Province
plt.figure(figsize=(10, 5))
sns.barplot(x=province_loss_ratio.index, y=province_loss_ratio.values, palette="Blues_d")
plt.title("Loss Ratio by Province")
plt.ylabel("Loss Ratio")
plt.xlabel("Province")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Loss Ratio by VehicleType
plt.figure(figsize=(8, 5))
sns.barplot(x=vehicle_type_loss_ratio.index, y=vehicle_type_loss_ratio.values, palette="Greens_d")
plt.title("Loss Ratio by Vehicle Type")
plt.ylabel("Loss Ratio")
plt.xlabel("Vehicle Type")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# Plot Loss Ratio by Gender
plt.figure(figsize=(6, 4))
sns.barplot(x=gender_loss_ratio.index, y=gender_loss_ratio.values, palette="Purples_d")
plt.title("Loss Ratio by Gender")
plt.ylabel("Loss Ratio")
plt.xlabel("Gender")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loss Ratio Analysis Documentation
#
# - **Overall Loss Ratio:**
#   The overall loss ratio for the portfolio is **1.0477**, indicating that, on average, claims paid slightly exceed premiums collected. A loss ratio above 1 suggests the portfolio is currently unprofitable.
#
# - **Loss Ratio by Province:**
#   There is significant variation in loss ratios across provinces. For example, Gauteng (1.22), KwaZulu-Natal (1.08), and Western Cape (1.06) have loss ratios above 1, indicating higher risk or lower profitability in these regions. In contrast, Northern Cape (0.28) and Eastern Cape (0.63) have much lower loss ratios, suggesting better profitability or lower risk.
#
# - **Loss Ratio by Vehicle Type:**
#   Heavy Commercial (1.63) and Medium Commercial (1.05) vehicles have the highest loss ratios, indicating these segments are less profitable and may require further investigation or pricing adjustments. Passenger Vehicles (1.05) are close to the overall average, while Buses (0.14) and Light Commercial vehicles (0.23) are much more profitable.
#
# - **Loss Ratio by Gender:**
#   The loss ratio is highest for the "Not specified" group (1.05), followed by Male (0.88) and Female (0.82). This suggests that policies where gender is not specified may carry higher risk, while female policyholders are associated with lower loss ratios.
#
# **Conclusion:**
# Loss ratios vary significantly by province, vehicle type, and gender. These insights can guide targeted risk management, pricing strategies, and further investigation into the drivers of high loss ratios in specific

# %% [markdown]
# #### Portfolio Loss Ratio Calculation and Distribution Analysis

# %%
# Calculate overall loss ratio
loss_ratio =  (df)

# Analyze by province and vehicle type
province_loss = calculate_loss_ratio(df, ['Province', 'VehicleType'])

# Plot distributions
numerical_cols = ['TotalPremium', 'TotalClaims']
categorical_cols = ['Province', 'VehicleType', 'Gender']
plot_distributions(df, numerical_cols, categorical_cols)
# Out:
# c:\Users\segni\Documents\GitHub\End-to-End-Insurance-Risk-Analytics-Predictive-Modeling\scripts\eda_stats.py:154: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum()

# %% [markdown]
# ### Interpretation of Feature Distributions Across Classes
#
# - **Gender:**
#   The "Not specified" class is the most dominant in the Gender feature, outnumbering both "Female" and "Male" categories. This class imbalance may affect analyses involving gender and could indicate missing or uncollected data for many records.
#
# - **VehicleType:**
#   The "Passenger Vehicle" class is overwhelmingly dominant compared to other vehicle types. This significant class imbalance suggests that most policies in the dataset are for passenger vehicles, which may bias model training and analysis toward this category.
#
# - **Province:**
#   The "Gauteng" province is much more represented than other provinces in the dataset. This imbalance means that insights and models may be more reflective of conditions in Gauteng than in other regions.
#
# **Conclusion:**
# Class imbalance in key features such as Gender, VehicleType, and Province should be considered during analysis and modeling. It may be necessary to apply techniques such as resampling or stratification to ensure fair and accurate insights across all classes.

# %% [markdown]
# #### Detecting Outliers in Numerical Features

# %%
# Detect outliers in numerical features
numerical_features = df.select_dtypes(include="float").columns.to_list()


print("outliers data points detected per numerical features")
outliers = detect_outliers(df, numerical_features)
for col, num_data_points in outliers.items():
    print(col, ": outliers data points detected", num_data_points)
# Out:
# outliers data points detected per numerical features
# Cylinders : outliers data points detected 34262
# cubiccapacity : outliers data points detected 5669
# kilowatts : outliers data points detected 2725
# NumberOfDoors : outliers data points detected 29647
# SumInsured : outliers data points detected 51
# CalculatedPremiumPerTerm : outliers data points detected 743
# TotalPremium : outliers data points detected 12470
# TotalClaims : outliers data points detected 1312

# %% [markdown]
# ### Outlier Detection Interpretation
#
# Outlier detection was performed on numerical features using the Z-score method. The Z-score measures how many standard deviations a data point is from the mean, and values with an absolute Z-score above a certain threshold (commonly 3) are flagged as outliers.
#
# #### Outliers Detected per Feature:
# - **mmcode:** 54,514 outliers detected
# - **Cylinders:** 34,262 outliers detected
# - **cubiccapacity:** 5,669 outliers detected
# - **kilowatts:** 2,725 outliers detected
# - **NumberOfDoors:** 29,647 outliers detected
# - **SumInsured:** 51 outliers detected
# - **CalculatedPremiumPerTerm:** 743 outliers detected
# - **TotalPremium:** 12,470 outliers detected
# - **TotalClaims:** 1,312 outliers detected
#
# **Interpretation:**
# A substantial number of outliers were found in several features, especially in `mmcode`, `Cylinders`, and `NumberOfDoors`. This may indicate data entry errors, rare or extreme cases, or genuine business anomalies. Features like `TotalPremium` and `TotalClaims` also have notable outliers, which could significantly impact statistical analysis and modeling. It is important to further investigate these outliers to determine whether they should be corrected, removed, or retained for analysis, as they may represent important risk or profitability signals in the insurance portfolio.

# %%
def plot_boxplots(df, numerical_features, figsize=(15, 8), whis=1.5, palette='viridis'):
    """
    Plots enhanced box plots for numerical features with outlier analysis.
    
    Parameters:
        df (pd.DataFrame): DataFrame containing the data
        numerical_features (list): List of numerical column names
        figsize (tuple): Figure size (width, height)
        whis (float): Whisker length (IQR multiplier)
        palette (str): Color palette name
    
    Returns:
        dict: Outlier statistics for each feature
    """
    import numpy as np
    
    # Calculate subplot grid dimensions
    n_cols = min(3, len(numerical_features))  # Ensure we don't create empty subplots
    n_rows = int(np.ceil(len(numerical_features) / n_cols))
    
    # Create figure with subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)
    
    # If only one feature, axes won't be an array
    if len(numerical_features) == 1:
        axes = np.array([axes])
    
    # Flatten axes array for easy iteration
    axes = axes.flatten()
    
    # Get a color palette with enough colors
    colors = sns.color_palette(palette, n_colors=len(numerical_features))
    
    # Dictionary to store outlier info
    outliers_info = {}
    
    # Plot each numerical feature
    for i, (col, ax) in enumerate(zip(numerical_features, axes)):
        # Create boxplot with enhanced styling
        sns.boxplot(
            y=df[col],
            ax=ax,
            color=colors[i],
            width=0.4,
            whis=whis,
            flierprops={
                'marker': 'o',
                'markersize': 5,
                'markerfacecolor': 'red',
                'markeredgecolor': 'orange',
                'alpha': 0.5
            }
        )
        
        # Calculate and annotate outliers
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - whis * iqr
        upper_bound = q3 + whis * iqr
        
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
        outliers_pct = (len(outliers) / len(df)) * 100
        
        # Store outlier info
        outliers_info[col] = {
            'count': len(outliers),
            'percentage': outliers_pct,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound
        }
        
        # Add annotations
        ax.set_title(f'{col}\nOutliers: {len(outliers)} ({outliers_pct:.1f}%)')
        ax.set_ylabel('')
        ax.grid(True, linestyle='--', alpha=0.7)
        
        # Rotate x-axis labels if needed
        plt.setp(ax.get_xticklabels(), rotation=45)
    
    # Hide unused subplots
    for j in range(len(numerical_features), len(axes)):
        axes[j].set_visible(False)
    
    plt.tight_layout()
    plt.show()
    
    return outliers_info

numerical_features = df.select_dtypes(include="float").columns.to_list()
outliers_infomation = plot_boxplots(df, numerical_features=numerical_features)

# %%
for col in outliers_infomation:
    print("**************************************")
    print(f"Feature: {col}")
    print(f"Outlier Count: {outliers_infomation[col]['count']}")
    print(f"Outlier Percentage: {outliers_infomation[col]['percentage']:.2f}%")
    print(f"Lower Bound: {outliers_infomation[col]['lower_bound']}")
    print(f"Upper Bound: {outliers_infomation[col]['upper_bound']}")
    print("**************************************")
# Out:
# **************************************
# Feature: Cylinders
# Outlier Count: 34814
# Outlier Percentage: 3.48%
# Lower Bound: 4.0
# Upper Bound: 4.0
# **************************************
# **************************************
# Feature: cubiccapacity
# Outlier Count: 56939
# Outlier Percentage: 5.69%
# Lower Bound: 1551.5
# Upper Bound: 3379.5
# **************************************
# **************************************
# Feature: kilowatts
# Outlier Count: 2175
# Outlier Percentage: 0.22%
# Lower Bound: 21.0
# Upper Bound: 165.0
# **************************************
# **************************************
# Feature: NumberOfDoors
# Outlier Count: 107260
# Outlier Percentage: 10.72%
# Lower Bound: 4.0
# Upper Bound: 4.0
# **************************************
# **************************************
# Feature: SumInsured
# Outlier Count: 104294
# Outlier Percentage: 10.43%
# Lower Bound: -362500.0
# Upper Bound: 617500.0
# **************************************
# **************************************
# Feature: CalculatedPremiumPerTerm
# Outlier Count: 175508
# Outlier Percentage: 17.55%
# Lower Bound: -126.938
# Upper Bound: 220.1628
# **************************************
# **************************************
# Feature: TotalPremium
# Outlier Count: 209042
# Outlier Percentage: 20.90%
# Lower Bound: -32.8947368421045
# Upper Bound: 54.8245614035075
# **************************************
# **************************************
# Feature: TotalClaims
# Outlier Count: 2793
# Outlier Percentage: 0.28%
# Lower Bound: 0.0
# Upper Bound: 0.0
# **************************************

# %%
monthly_trends = analyze_temporal_trends(df)

# %%
geo_analysis = analyze_by_geography(df)

# %% [markdown]
# ## **Lost Ratio by Province and vehicle**

# %%
plot_creative_visualizations(df)
# Out:
# c:\Users\segni\Documents\GitHub\End-to-End-Insurance-Risk-Analytics-Predictive-Modeling\scripts\eda_stats.py:376: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum()
